# %%
import time
from random import randint
import random

b =int(input("Введите желаемый размер списка :"))
c =int(input("Введите минимальное число :"))
d =int(input("Введите максимальное число :"))


a = []
for i in range(b):
    a.append(randint(c, d))
a = sorted(a)
print(a)


start_time = time.time()
def Binary(a) :

    print("Реализация Бинарного поиска :")
    # искомое число
    value = int(input("Введите число которое хотите найти : "))

    mid = len(a) // 2
    low = 0
    high = len(a) - 1

    while a[mid] != value and low <= high:
        if value > a[mid]:
            low = mid + 1
        else:
            high = mid - 1
        mid = (low + high) // 2

    if low > high:
        print("No value")
    else:
        print("ID =", mid+1)


Binary(a)

print("Время поиска Бинарной фигней : " , (time.time()-start_time))

x =int(input("Какое Число хотите добавить в  список ? :"))
a.append(x)
print(a)
boba = input("Хотите еще раз отсортировать список ? :")
if boba != "Да":
    print(a)
else:
    print(sorted(a))
    a =sorted(a)

print("Поиск  Фибоначчи :")
fib = int(input("ввидете число которое ищите ?"))

def FibonacciSearch(lys, val):
    fibM_minus_2 = 0
    fibM_minus_1 = 1
    fibM = fibM_minus_1 + fibM_minus_2
    while (fibM < len(lys)):
        fibM_minus_2 = fibM_minus_1
        fibM_minus_1 = fibM
        fibM = fibM_minus_1 + fibM_minus_2
    index = -1;
    while (fibM > 1):
        i = min(index + fibM_minus_2, (len(lys)-1))
        if (lys[i] < val):
            fibM = fibM_minus_1
            fibM_minus_1 = fibM_minus_2
            fibM_minus_2 = fibM - fibM_minus_1
            index = i
        elif (lys[i] > val):
            fibM = fibM_minus_2
            fibM_minus_1 = fibM_minus_1 - fibM_minus_2
            fibM_minus_2 = fibM - fibM_minus_1
        else :
            return i
    if(fibM_minus_1 and index < (len(lys)-1) and lys[index+1] == val):
        return index+1;
    return print("NO VALUE")

print(FibonacciSearch(a, fib))

print("Интерполяционный Поиск : ")
inter = int(input("Введите искомый элемент : "))
def InterpolationSearch(lys, val):
    low = 0
    high = (len(lys) - 1)
    while low <= high and val >= lys[low] and val <= lys[high]:
        index = low + int(((float(high - low) / ( lys[high] - lys[low])) * ( val - lys[low])))
        if lys[index] == val:
            return index
        if lys[index] < val:
            low = index + 1;
        else:
            high = index - 1;
    return print("NO VALUE")


print(InterpolationSearch(a,inter))
# Out:
# Введите желаемый размер списка :150
# Введите минимальное число :-100
# Введите максимальное число :100
# [-97, -96, -90, -88, -87, -87, -85, -85, -84, -80, -80, -79, -78, -77, -76, -76, -74, -72, -72, -70, -64, -64, -63, -62, -59, -57, -57, -56, -56, -55, -54, -53, -51, -51, -51, -47, -46, -46, -45, -45, -44, -43, -39, -39, -37, -36, -34, -34, -33, -32, -31, -31, -31, -29, -27, -25, -24, -19, -18, -16, -16, -15, -13, -13, -12, -10, -9, -9, -8, -6, -4, -3, -1, 1, 3, 6, 7, 8, 8, 8, 9, 12, 13, 13, 15, 19, 22, 22, 23, 25, 25, 27, 27, 27, 27, 32, 32, 32, 33, 36, 39, 41, 42, 43, 43, 44, 44, 44, 44, 46, 47, 48, 49, 51, 51, 52, 54, 57, 58, 59, 60, 61, 62, 63, 68, 69, 73, 74, 74, 75, 75, 75, 75, 78, 81, 83, 85, 85, 86, 89, 91, 93, 94, 94, 95, 96, 97, 98, 100, 100]
# Реализация Бинарного поиска :
# Введите число которое хотите найти : 48
# ID = 112
# Время поиска Бинарной фигней :  11.605321645736694
# Какое Число хотите добавить в  список ? :3
# ...
